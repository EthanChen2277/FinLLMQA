# %%
from py2neo import Graph,Node,Relationship,NodeMatcher
import pandas as pd
import numpy as np
from multiprocessing.pool import ThreadPool
import akshare as ak
import logging
from datetime import datetime, timedelta
from tqdm import tqdm
import os
from finllmqa.api.core import NEO4J_API_URL, STOCK_KG_USER, STOCK_KG_PW

pool = ThreadPool(10)
# 连接Neo4j数据库
graph = Graph('http://192.168.30.158:7474', auth=(STOCK_KG_USER, STOCK_KG_PW), name='neo4j')
matcher = NodeMatcher(graph)

# %%
def get_logger(name):
    logger = logging.getLogger(name)
    logger.setLevel(logging.INFO)
    
    # 以下两行是为了在jupyter notebook 中不重复输出日志
    if logger.root.handlers:
        logger.root.handlers[0].setLevel(logging.WARNING)
 
    handler_stdout = logging.StreamHandler()
    handler_stdout.setLevel(logging.INFO)
    handler_stdout.setFormatter(logging.Formatter('%(asctime)s - %(levelname)s - %(message)s'))
    logger.addHandler(handler_stdout)
 
    handler_file = logging.FileHandler('log_file.log', encoding='utf-8')
    handler_file.setLevel(logging.DEBUG)
    handler_file.setFormatter(logging.Formatter('%(asctime)s - %(name)s - %(levelname)s - %(message)s'))
    logger.addHandler(handler_file)
 
    return logger
log = get_logger(None)

# %% [markdown]
# # Construct financial knowledge graph of stock

# %%
# get stock data
df_stock_code = ak.stock_info_a_code_name()
stock_code_list = df_stock_code['code'].to_list()
# Out:
#   0%|          | 0/13 [00:00<?, ?it/s]

# %%
# create stock node constraint
cypher = 'CREATE CONSTRAINT IF NOT EXISTS FOR (n:股票) REQUIRE n.代码 IS UNIQUE'
graph.run(cypher=cypher)

# create stock node
for code, name in df_stock_code.values:
    stock_node = Node('股票', 代码=code, 名称=name, name=name)
    try:
        graph.create(stock_node)
    except:
        continue

# %% [markdown]
# ## 1. Financial Abstract

# %%
# create financial abstract constraint
cypher = 'CREATE CONSTRAINT IF NOT EXISTS FOR (n:财务指标) REQUIRE (n.股票代码, n.指标类型) IS UNIQUE'
graph.run(cypher=cypher)
df_fin_ab_demo = ak.stock_financial_abstract(symbol='000001')
for abstract_type in df_fin_ab_demo['选项']:
    # create financial abstract indicators constraint
    cypher = f'CREATE CONSTRAINT IF NOT EXISTS FOR (n:{abstract_type}) REQUIRE (n.股票代码, n.报告期) IS UNIQUE'
    graph.run(cypher=cypher)

for code in tqdm(stock_code_list):
    # stock = matcher.match("股票", 代码=code).first()
    # fin_ab = matcher.match("财务指标", 股票代码=code, 指标类型='常用指标').first()
    # if stock is not None and fin_ab is not None:
    #     continue
    # get financial abstract info
    try:
        df_fin_ab = ak.stock_financial_abstract(symbol=code).copy()
    except:
        log.warning(f'Can not get {code} financial abstract info')
        
    for abstract_type, df_group in df_fin_ab.groupby('选项'):
        # create financial abstract node
        fin_ab_node = Node('财务指标', 股票代码=code, 指标类型=abstract_type, name=abstract_type)
        try:
            graph.create(fin_ab_node)
        except:
            pass

        # create stock - financial abstract relationship
        stock = matcher.match("股票", 代码=code).first()
        fin_ab = matcher.match("财务指标", 股票代码=code, 指标类型=abstract_type).first()
        realation = Relationship(stock, '基本面', fin_ab)
        try:
            graph.create(realation)
        except:
            pass

        # create financial abstract indicators node
        df = df_group.drop('选项', axis=1).set_index('指标').copy()
        df = df.T.reset_index(drop=False, names='报告期').copy()
        df['股票代码'] = code
        df['报告期'] = pd.to_datetime(df['报告期'])
        df = df[df['报告期'] > datetime(2020,12,31)]
        df['报告期'] = df['报告期'].dt.strftime('%Y-%m-%d')
        df = df.fillna('null').copy()
        for record in df.to_dict('records'):
            record.update({'name': record['报告期']})
            fin_ab_indicator_node = Node(abstract_type, **record)
            try:
                graph.create(fin_ab_indicator_node)
            except:
                pass

        # create financial abstract-financial abstract indicators relationship
        fin_ab = matcher.match("财务指标",股票代码=code, 指标类型=abstract_type).first()
        fin_ab_indicator_ls = matcher.match(abstract_type, 股票代码=code)
        for fin_ab_indicator in fin_ab_indicator_ls: 
            realation = Relationship(fin_ab, '按报告期', fin_ab_indicator)
            try:
                graph.create(realation)
            except:
                pass

# %% [markdown]
# ## 2. Research Report

# %%
def _process_reasearch_report(df: pd.DataFrame):
    df['日期'] = pd.to_datetime(df['日期'])
    df = df[df['日期'] >= datetime.now() - timedelta(365)].copy()
    df_rsh_repo = df[['股票代码']].drop_duplicates().copy()
    df_rsh_repo['近一年研报数量'] = len(df)
    df_rsh_repo['买入/增持评级数量'] = len(df[df['东财评级'].isin(['买入', '增持'])])
    if df['2023-盈利预测-收益'].isna().sum() == len(df):
        df_rsh_repo['2023盈利预测-收益'] = 'null'
    else:
        df_rsh_repo['2023盈利预测-收益'] = df[~df['2023-盈利预测-收益'].isna()]['2023-盈利预测-收益'].mean()
    if df['2023-盈利预测-市盈率'].isna().sum() == len(df):
        df_rsh_repo['2023盈利预测-市盈率'] = 'null'
    else:
        df_rsh_repo['2023盈利预测-市盈率'] = df[~df['2023-盈利预测-市盈率'].isna()]['2023-盈利预测-市盈率'].mean()
    if df['2024-盈利预测-收益'].isna().sum() == len(df):
        df_rsh_repo['2024盈利预测-收益'] = 'null'
    else:
        df_rsh_repo['2024盈利预测-收益'] = df[~df['2024-盈利预测-收益'].isna()]['2024-盈利预测-收益'].mean()
    if df['2024-盈利预测-市盈率'].isna().sum() == len(df):
        df_rsh_repo['2024盈利预测-市盈率'] = 'null'
    else:
        df_rsh_repo['2024盈利预测-市盈率'] = df[~df['2024-盈利预测-市盈率'].isna()]['2024-盈利预测-市盈率'].mean()
    return df_rsh_repo

# %%
df = ak.stock_research_report_em(symbol='000001')

# %%
_process_reasearch_report(df)

# %%
# create research report constraint
cypher = 'CREATE CONSTRAINT IF NOT EXISTS FOR (n:个股研报) REQUIRE (n.股票代码) IS UNIQUE'
graph.run(cypher=cypher)


# get research report info
df_rsh_repo_ls = []
for code in tqdm(stock_code_list):
    try:
        df_rsh_repo = ak.stock_research_report_em(symbol=code).copy()
        df_rsh_repo = _process_reasearch_report(df_rsh_repo)
        df_rsh_repo_ls.append(df_rsh_repo)
    except:
        continue
        # log.warning(f'{code} has no research report info')
if len(df_rsh_repo_ls) == 0:
    raise ConnectionError('Can not get stock research report from akshare')
else:
    df_rsh_repo = pd.concat(df_rsh_repo_ls, ignore_index=True)
    
    
for record in tqdm(df_rsh_repo.to_dict('records')):
    # create research report nodeb
    rsh_report_node = Node('个股研报', name='个股研报', **record)
    try:
        graph.create(rsh_report_node)
    except:
        pass
    
    # create stock - main business composition relationship
    stock = matcher.match("股票", 代码=record['股票代码']).first()
    if stock is None:
        continue
    rsh_report = matcher.match("个股研报", 股票代码=record['股票代码']).first()
    realation = Relationship(stock, '基本面', rsh_report)
    try:
        graph.create(realation)
    except:
        pass

# %% [markdown]
# ## 3. Main Business Composition

# %%
def assign_exchange_prefix(code: str):
    if code.startswith('0') or code.startswith('3'):
        code = 'SZ' + code
    else:
        code = 'SH' + code
    return code

# %%
# create main business composition constraint
cypher = 'CREATE CONSTRAINT IF NOT EXISTS FOR (n:主营构成) REQUIRE (n.股票代码, n.报告期) IS UNIQUE'
graph.run(cypher=cypher)

# create main business constraint
cypher = 'CREATE CONSTRAINT IF NOT EXISTS FOR (n:主营业务) REQUIRE (n.股票代码, n.报告期, n.业务名称) IS UNIQUE'
graph.run(cypher=cypher)


for code in tqdm(stock_code_list):
    # get main business info
    try:
        symbol = assign_exchange_prefix(code)
        df_main_business = ak.stock_zygc_em(symbol=symbol).copy()
        df_main_business = df_main_business.fillna('nan').copy()
    except:
        log.warning(f'Can not get {code} main business info')
        continue
        
    df_main_business = df_main_business[df_main_business['分类类型'] == '按产品分类'].copy()
    df_main_business['报告日期'] = pd.to_datetime(df_main_business['报告日期'])
    df_main_business = df_main_business[df_main_business['报告日期'] > datetime(2020,12,31)].copy()
    df_main_business['报告日期'] = df_main_business['报告日期'].dt.strftime('%Y-%m-%d')
    for report_time, df_group in df_main_business.groupby('报告日期'):
        # create main business composition node
        main_bus_compo_node = Node('主营构成', 股票代码=code, 报告期=report_time, name=report_time)
        try:
            graph.create(main_bus_compo_node)
        except:
            pass

        # create stock - main business composition relationship
        stock = matcher.match("股票", 代码=code).first()
        main_bus_compo = matcher.match("主营构成", 股票代码=code, 报告期=report_time).first()
        realation = Relationship(stock, '基本面', main_bus_compo)
        try:
            graph.create(realation)
        except:
            pass

        # create main business node
        df_group = df_group[['股票代码', '报告日期', '主营构成', '主营收入', '收入比例', '主营成本',
                             '成本比例', '主营利润', '利润比例', '毛利率']].copy()
        df_group = df_group.rename(columns={'主营构成': '业务名称', '报告日期': '报告期'})
        for record in df_group.to_dict('records'):
            record.update({'name': record['业务名称']})
            main_business_node = Node('主营业务', **record)
            try:
                graph.create(main_business_node)
            except:
                pass

        # create main business composition-main business relationship
        main_bus_compo = matcher.match("主营构成", 股票代码=code, 报告期=report_time).first()
        main_bus_ls = matcher.match("主营业务", 股票代码=code, 报告期=report_time)
        for main_bus in main_bus_ls: 
            realation = Relationship(main_bus_compo, '按产品分类', main_bus)
            try:
                graph.create(realation)
            except:
                pass

# %% [markdown]
# ## 4. Main Shareholders

# %%
def assign_exchange_prefix(code: str):
    if code.startswith('0') or code.startswith('3'):
        code = 'sz' + code
    else:
        code = 'sh' + code
    return code

# %%
# create main shareholders constraint
cypher = 'CREATE CONSTRAINT IF NOT EXISTS FOR (n:主要股东) REQUIRE (n.股票代码, n.报告期) IS UNIQUE'
graph.run(cypher=cypher)

# create shares holding constraint
cypher = 'CREATE CONSTRAINT IF NOT EXISTS FOR (n:持股信息) REQUIRE (n.股票代码, n.报告期, n.股东名称) IS UNIQUE'
graph.run(cypher=cypher)

report_time_ls = ['20210331', '20210630', '20210930', '20211231', 
                  '20220331', '20220630', '20220930', '20221231', 
                  '20230331', '20230630', '20230930', '20231231']

for code in tqdm(stock_code_list):
    # get main shareholders info
    for report_time in report_time_ls:
        try:
            symbol = assign_exchange_prefix(code)
            df_main_shareholders = ak.stock_gdfx_top_10_em(symbol=symbol, date=report_time).copy()
        except:
            log.warning(f'Can not get {code} {report_time} main shareholders info')
            continue

        df_main_shareholders = df_main_shareholders[:3].fillna('nan').copy()
        # create main shareholders node
        main_shareholders_node = Node('主要股东', 股票代码=code, 报告期=report_time, name=report_time)
        try:
            graph.create(main_shareholders_node)
        except:
            break

        # create stock - main shareholders relationship
        stock = matcher.match("股票", 代码=code).first()
        main_shareholders = matcher.match("主要股东", 股票代码=code, 报告期=report_time).first()
        realation = Relationship(stock, '基本面', main_shareholders)
        try:
            graph.create(realation)
        except:
            pass

        # create shares holding node
        for record in df_main_shareholders.to_dict('records'):
            record.update({'name': record['股东名称'], '股票代码': code, '报告期': report_time})
            shares_holding = Node('持股信息', **record)
            try:
                graph.create(shares_holding)
            except:
                break

        # create main business composition-main business relationship
        main_shareholders = matcher.match("主要股东", 股票代码=code, 报告期=report_time).first()
        shares_holding_ls = matcher.match("持股信息", 股票代码=code, 报告期=report_time)
        for shares_holding in shares_holding_ls: 
            realation = Relationship(main_shareholders, '按持股比例', shares_holding)
            try:
                graph.create(realation)
            except:
                break
# Out:
#   0%|          | 0/5363 [00:00<?, ?it/s]
#   8%|▊         | 430/5363 [02:23<25:50,  3.18it/s]2024-04-11 11:23:31,282 - root - WARNING - Can not get 001201 20210331 main shareholders info
# 2024-04-11 11:23:31,282 - WARNING - Can not get 001201 20210331 main shareholders info
#   8%|▊         | 431/5363 [02:23<35:12,  2.33it/s]2024-04-11 11:23:31,892 - root - WARNING - Can not get 001202 20210331 main shareholders info
# 2024-04-11 11:23:31,892 - WARNING - Can not get 001202 20210331 main shareholders info
#   8%|▊         | 432/5363 [02:24<37:24,  2.20it/s]2024-04-11 11:23:32,608 - root - WARNING - Can not get 001203 20210331 main shareholders info
# 2024-04-11 11:23:32,608 - WARNING - Can not get 001203 20210331 main shareholders info
#   8%|▊         | 433/5363 [02:25<45:05,  1.82it/s]2024-04-11 11:23:33,192 - root - WARNING - Can not get 001205 20210331 main shareholders info
# 2024-04-11 11:23:33,192 - WARNING - Can not get 001205 20210331 main shareholders info
#   8%|▊         | 434/5363 [02:25<43:51,  1.87it/s]2024-04-11 11:23:33,696 - root - WARNING - Can not get 001206 20210331 main shareholders info
# 2024-04-11 11:23:33,696 - WARNING - Can not get 001206 20210331 main shareholders info
#   8%|▊         | 435/5363 [02:26<42:53,  1.91it/s]2024-04-11 11:23:34,182 - root - WARNING - Can not get 001207 20210331 main shareholders info
# 2024-04-11 11:23:34,182 - WARNING - Can not get 001207 20210331 main shareholders info
#   8%|▊         | 436/5363 [02:26<48:46,  1.68it/s]2024-04-11 11:23:34,963 - root - WARNING - Can not get 001208 20210331 main shareholders info
# 2024-04-11 11:23:34,963 - WARNING - Can not get 001208 20210331 main shareholders info
#   8%|▊         | 437/5363 [02:27<47:48,  1.72it/s]2024-04-11 11:23:35,554 - root - WARNING - Can not get 001209 20210331 main shareholders info
# 2024-04-11 11:23:35,554 - WARNING - Can not get 001209 20210331 main shareholders info
#   8%|▊         | 438/5363 [02:28<50:32,  1.62it/s]2024-04-11 11:23:36,258 - root - WARNING - Can not get 001210 20210331 main shareholders info
# 2024-04-11 11:23:36,258 - WARNING - Can not get 001210 20210331 main shareholders info
#   8%|▊         | 439/5363 [02:28<52:32,  1.56it/s]2024-04-11 11:23:36,982 - root - WARNING - Can not get 001211 20210331 main shareholders info
# 2024-04-11 11:23:36,982 - WARNING - Can not get 001211 20210331 main shareholders info
#   8%|▊         | 440/5363 [02:29<52:06,  1.57it/s]2024-04-11 11:23:37,593 - root - WARNING - Can not get 001212 20210331 main shareholders info
# 2024-04-11 11:23:37,593 - WARNING - Can not get 001212 20210331 main shareholders info
# 2024-04-11 11:23:37,892 - root - WARNING - Can not get 001212 20210630 main shareholders info
# 2024-04-11 11:23:37,892 - WARNING - Can not get 001212 20210630 main shareholders info
#   8%|▊         | 441/5363 [02:30<59:29,  1.38it/s]2024-04-11 11:23:38,412 - root - WARNING - Can not get 001213 20210331 main shareholders info
# 2024-04-11 11:23:38,412 - WARNING - Can not get 001213 20210331 main shareholders info
# 2024-04-11 11:23:38,627 - root - WARNING - Can not get 001213 20210630 main shareholders info
# 2024-04-11 11:23:38,627 - WARNING - Can not get 001213 20210630 main shareholders info
#   8%|▊         | 442/5363 [02:31<1:01:15,  1.34it/s]2024-04-11 11:23:39,519 - root - WARNING - Can not get 001215 20210331 main shareholders info
# 2024-04-11 11:23:39,519 - WARNING - Can not get 001215 20210331 main shareholders info
# 2024-04-11 11:23:39,771 - root - WARNING - Can not get 001215 20210630 main shareholders info
# 2024-04-11 11:23:39,771 - WARNING - Can not get 001215 20210630 main shareholders info
#   8%|▊         | 443/5363 [02:32<1:12:34,  1.13it/s]2024-04-11 11:23:40,490 - root - WARNING - Can not get 001216 20210331 main shareholders info
# 2024-04-11 11:23:40,490 - WARNING - Can not get 001216 20210331 main shareholders info
# 2024-04-11 11:23:40,956 - root - WARNING - Can not get 001216 20210630 main shareholders info
# 2024-04-11 11:23:40,956 - WARNING - Can not get 001216 20210630 main shareholders info
#   8%|▊         | 444/5363 [02:33<1:17:30,  1.06it/s]2024-04-11 11:23:41,715 - root - WARNING - Can not get 001217 20210331 main shareholders info
# 2024-04-11 11:23:41,715 - WARNING - Can not get 001217 20210331 main shareholders info
# 2024-04-11 11:23:41,993 - root - WARNING - Can not get 001217 20210630 main shareholders info
# 2024-04-11 11:23:41,993 - WARNING - Can not get 001217 20210630 main shareholders info
#   8%|▊         | 445/5363 [02:34<1:19:29,  1.03it/s]2024-04-11 11:23:42,569 - root - WARNING - Can not get 001218 20210331 main shareholders info
# 2024-04-11 11:23:42,569 - WARNING - Can not get 001218 20210331 main shareholders info
# 2024-04-11 11:23:42,919 - root - WARNING - Can not get 001218 20210630 main shareholders info
# 2024-04-11 11:23:42,919 - WARNING - Can not get 001218 20210630 main shareholders info
#   8%|▊         | 446/5363 [02:35<1:17:55,  1.05it/s]2024-04-11 11:23:43,510 - root - WARNING - Can not get 001219 20210331 main shareholders info
# 2024-04-11 11:23:43,510 - WARNING - Can not get 001219 20210331 main shareholders info
# 2024-04-11 11:23:43,829 - root - WARNING - Can not get 001219 20210630 main shareholders info
# 2024-04-11 11:23:43,829 - WARNING - Can not get 001219 20210630 main shareholders info
#   8%|▊         | 447/5363 [02:36<1:15:32,  1.08it/s]2024-04-11 11:23:44,418 - root - WARNING - Can not get 001222 20210331 main shareholders info
# 2024-04-11 11:23:44,418 - WARNING - Can not get 001222 20210331 main shareholders info
# 2024-04-11 11:23:44,755 - root - WARNING - Can not get 001222 20210630 main shareholders info
# 2024-04-11 11:23:44,755 - WARNING - Can not get 001222 20210630 main shareholders info
# 2024-04-11 11:23:45,214 - root - WARNING - Can not get 001222 20210930 main shareholders info
# 2024-04-11 11:23:45,214 - WARNING - Can not get 001222 20210930 main shareholders info
# 2024-04-11 11:23:45,510 - root - WARNING - Can not get 001222 20211231 main shareholders info
# 2024-04-11 11:23:45,510 - WARNING - Can not get 001222 20211231 main shareholders info
# 2024-04-11 11:23:45,844 - root - WARNING - Can not get 001222 20220331 main shareholders info
# 2024-04-11 11:23:45,844 - WARNING - Can not get 001222 20220331 main shareholders info
# 2024-04-11 11:23:46,094 - root - WARNING - Can not get 001222 20220630 main shareholders info
# 2024-04-11 11:23:46,094 - WARNING - Can not get 001222 20220630 main shareholders info
#   8%|▊         | 448/5363 [02:38<1:49:04,  1.33s/it]2024-04-11 11:23:46,685 - root - WARNING - Can not get 001223 20210331 main shareholders info
# 2024-04-11 11:23:46,685 - WARNING - Can not get 001223 20210331 main shareholders info
# 2024-04-11 11:23:47,179 - root - WARNING - Can not get 001223 20210630 main shareholders info
# 2024-04-11 11:23:47,179 - WARNING - Can not get 001223 20210630 main shareholders info
# 2024-04-11 11:23:47,722 - root - WARNING - Can not get 001223 20210930 main shareholders info
# 2024-04-11 11:23:47,722 - WARNING - Can not get 001223 20210930 main shareholders info
# 2024-04-11 11:23:47,975 - root - WARNING - Can not get 001223 20211231 main shareholders info
# 2024-04-11 11:23:47,975 - WARNING - Can not get 001223 20211231 main shareholders info
# 2024-04-11 11:23:48,270 - root - WARNING - Can not get 001223 20220331 main shareholders info
# 2024-04-11 11:23:48,270 - WARNING - Can not get 001223 20220331 main shareholders info
# 2024-04-11 11:23:48,551 - root - WARNING - Can not get 001223 20220630 main shareholders info
# 2024-04-11 11:23:48,551 - WARNING - Can not get 001223 20220630 main shareholders info
# 2024-04-11 11:23:48,790 - root - WARNING - Can not get 001223 20220930 main shareholders info
# 2024-04-11 11:23:48,790 - WARNING - Can not get 001223 20220930 main shareholders info
#   8%|▊         | 449/5363 [02:41<2:22:52,  1.74s/it]2024-04-11 11:23:49,491 - root - WARNING - Can not get 001225 20210331 main shareholders info
# 2024-04-11 11:23:49,491 - WARNING - Can not get 001225 20210331 main shareholders info
# 2024-04-11 11:23:49,829 - root - WARNING - Can not get 001225 20210630 main shareholders info
# 2024-04-11 11:23:49,829 - WARNING - Can not get 001225 20210630 main shareholders info
# 2024-04-11 11:23:50,283 - root - WARNING - Can not get 001225 20210930 main shareholders info
# 2024-04-11 11:23:50,283 - WARNING - Can not get 001225 20210930 main shareholders info
# 2024-04-11 11:23:50,559 - root - WARNING - Can not get 001225 20211231 main shareholders info
# 2024-04-11 11:23:50,559 - WARNING - Can not get 001225 20211231 main shareholders info
# 2024-04-11 11:23:50,822 - root - WARNING - Can not get 001225 20220331 main shareholders info
# 2024-04-11 11:23:50,822 - WARNING - Can not get 001225 20220331 main shareholders info
# 2024-04-11 11:23:51,336 - root - WARNING - Can not get 001225 20220630 main shareholders info
# 2024-04-11 11:23:51,336 - WARNING - Can not get 001225 20220630 main shareholders info
# 2024-04-11 11:23:51,644 - root - WARNING - Can not get 001225 20220930 main shareholders info
# 2024-04-11 11:23:51,644 - WARNING - Can not get 001225 20220930 main shareholders info
#   8%|▊         | 450/5363 [02:44<2:50:42,  2.08s/it]2024-04-11 11:23:52,238 - root - WARNING - Can not get 001226 20210331 main shareholders info
# 2024-04-11 11:23:52,238 - WARNING - Can not get 001226 20210331 main shareholders info
# 2024-04-11 11:23:52,593 - root - WARNING - Can not get 001226 20210630 main shareholders info
# 2024-04-11 11:23:52,593 - WARNING - Can not get 001226 20210630 main shareholders info
# 2024-04-11 11:23:52,933 - root - WARNING - Can not get 001226 20210930 main shareholders info
# 2024-04-11 11:23:52,933 - WARNING - Can not get 001226 20210930 main shareholders info
# 2024-04-11 11:23:53,237 - root - WARNING - Can not get 001226 20211231 main shareholders info
# 2024-04-11 11:23:53,237 - WARNING - Can not get 001226 20211231 main shareholders info
# 2024-04-11 11:23:53,521 - root - WARNING - Can not get 001226 20220331 main shareholders info
# 2024-04-11 11:23:53,521 - WARNING - Can not get 001226 20220331 main shareholders info
#   8%|▊         | 451/5363 [02:46<2:45:14,  2.02s/it]2024-04-11 11:23:54,130 - root - WARNING - Can not get 001227 20210331 main shareholders info
# 2024-04-11 11:23:54,130 - WARNING - Can not get 001227 20210331 main shareholders info
#   8%|▊         | 452/5363 [02:46<2:10:20,  1.59s/it]2024-04-11 11:23:54,724 - root - WARNING - Can not get 001228 20210331 main shareholders info
# 2024-04-11 11:23:54,724 - WARNING - Can not get 001228 20210331 main shareholders info
# 2024-04-11 11:23:54,971 - root - WARNING - Can not get 001228 20210630 main shareholders info
# 2024-04-11 11:23:54,971 - WARNING - Can not get 001228 20210630 main shareholders info
# 2024-04-11 11:23:55,223 - root - WARNING - Can not get 001228 20210930 main shareholders info
# 2024-04-11 11:23:55,223 - WARNING - Can not get 001228 20210930 main shareholders info
# 2024-04-11 11:23:55,524 - root - WARNING - Can not get 001228 20211231 main shareholders info
# 2024-04-11 11:23:55,524 - WARNING - Can not get 001228 20211231 main shareholders info
# 2024-04-11 11:23:55,784 - root - WARNING - Can not get 001228 20220331 main shareholders info
# 2024-04-11 11:23:55,784 - WARNING - Can not get 001228 20220331 main shareholders info
#   8%|▊         | 453/5363 [02:48<2:14:08,  1.64s/it]2024-04-11 11:23:56,599 - root - WARNING - Can not get 001229 20210331 main shareholders info
# 2024-04-11 11:23:56,599 - WARNING - Can not get 001229 20210331 main shareholders info
# 2024-04-11 11:23:56,937 - root - WARNING - Can not get 001229 20210630 main shareholders info
# 2024-04-11 11:23:56,937 - WARNING - Can not get 001229 20210630 main shareholders info
# 2024-04-11 11:23:57,315 - root - WARNING - Can not get 001229 20210930 main shareholders info
# 2024-04-11 11:23:57,315 - WARNING - Can not get 001229 20210930 main shareholders info
# 2024-04-11 11:23:57,594 - root - WARNING - Can not get 001229 20211231 main shareholders info
# 2024-04-11 11:23:57,594 - WARNING - Can not get 001229 20211231 main shareholders info
# 2024-04-11 11:23:57,858 - root - WARNING - Can not get 001229 20220331 main shareholders info
# 2024-04-11 11:23:57,858 - WARNING - Can not get 001229 20220331 main shareholders info
#   8%|▊         | 454/5363 [02:50<2:23:00,  1.75s/it]2024-04-11 11:23:58,464 - root - WARNING - Can not get 001230 20210331 main shareholders info
# 2024-04-11 11:23:58,464 - WARNING - Can not get 001230 20210331 main shareholders info
# 2024-04-11 11:23:58,721 - root - WARNING - Can not get 001230 20210630 main shareholders info
# 2024-04-11 11:23:58,721 - WARNING - Can not get 001230 20210630 main shareholders info
# 2024-04-11 11:23:58,985 - root - WARNING - Can not get 001230 20210930 main shareholders info
# 2024-04-11 11:23:58,985 - WARNING - Can not get 001230 20210930 main shareholders info
# 2024-04-11 11:23:59,234 - root - WARNING - Can not get 001230 20211231 main shareholders info
# 2024-04-11 11:23:59,234 - WARNING - Can not get 001230 20211231 main shareholders info
# 2024-04-11 11:23:59,527 - root - WARNING - Can not get 001230 20220331 main shareholders info
# 2024-04-11 11:23:59,527 - WARNING - Can not get 001230 20220331 main shareholders info
#   8%|▊         | 455/5363 [02:52<2:21:27,  1.73s/it]2024-04-11 11:24:00,243 - root - WARNING - Can not get 001231 20210331 main shareholders info
# 2024-04-11 11:24:00,243 - WARNING - Can not get 001231 20210331 main shareholders info
# 2024-04-11 11:24:00,533 - root - WARNING - Can not get 001231 20210630 main shareholders info
# 2024-04-11 11:24:00,533 - WARNING - Can not get 001231 20210630 main shareholders info
# 2024-04-11 11:24:00,903 - root - WARNING - Can not get 001231 20210930 main shareholders info
# 2024-04-11 11:24:00,903 - WARNING - Can not get 001231 20210930 main shareholders info
#   9%|▊         | 456/5363 [02:53<2:17:26,  1.68s/it]2024-04-11 11:24:01,707 - root - WARNING - Can not get 001234 20210331 main shareholders info
# 2024-04-11 11:24:01,707 - WARNING - Can not get 001234 20210331 main shareholders info
# 2024-04-11 11:24:01,955 - root - WARNING - Can not get 001234 20210630 main shareholders info
# 2024-04-11 11:24:01,955 - WARNING - Can not get 001234 20210630 main shareholders info
# 2024-04-11 11:24:02,209 - root - WARNING - Can not get 001234 20210930 main shareholders info
# 2024-04-11 11:24:02,209 - WARNING - Can not get 001234 20210930 main shareholders info
#   9%|▊         | 457/5363 [02:54<2:02:13,  1.49s/it]2024-04-11 11:24:02,856 - root - WARNING - Can not get 001236 20210331 main shareholders info
# 2024-04-11 11:24:02,856 - WARNING - Can not get 001236 20210331 main shareholders info
# 2024-04-11 11:24:03,382 - root - WARNING - Can not get 001236 20210630 main shareholders info
# 2024-04-11 11:24:03,382 - WARNING - Can not get 001236 20210630 main shareholders info
# 2024-04-11 11:24:03,726 - root - WARNING - Can not get 001236 20210930 main shareholders info
# 2024-04-11 11:24:03,726 - WARNING - Can not get 001236 20210930 main shareholders info
# 2024-04-11 11:24:04,036 - root - WARNING - Can not get 001236 20211231 main shareholders info
# 2024-04-11 11:24:04,036 - WARNING - Can not get 001236 20211231 main shareholders info
# 2024-04-11 11:24:04,333 - root - WARNING - Can not get 001236 20220331 main shareholders info
# 2024-04-11 11:24:04,333 - WARNING - Can not get 001236 20220331 main shareholders info
#   9%|▊         | 458/5363 [02:56<2:18:15,  1.69s/it]2024-04-11 11:24:05,119 - root - WARNING - Can not get 001238 20210331 main shareholders info
# 2024-04-11 11:24:05,119 - WARNING - Can not get 001238 20210331 main shareholders info
# 2024-04-11 11:24:05,672 - root - WARNING - Can not get 001238 20210630 main shareholders info
# 2024-04-11 11:24:05,672 - WARNING - Can not get 001238 20210630 main shareholders info
# 2024-04-11 11:24:05,999 - root - WARNING - Can not get 001238 20210930 main shareholders info
# 2024-04-11 11:24:05,999 - WARNING - Can not get 001238 20210930 main shareholders info
# 2024-04-11 11:24:06,242 - root - WARNING - Can not get 001238 20211231 main shareholders info
# 2024-04-11 11:24:06,242 - WARNING - Can not get 001238 20211231 main shareholders info
# 2024-04-11 11:24:06,502 - root - WARNING - Can not get 001238 20220331 main shareholders info
# 2024-04-11 11:24:06,502 - WARNING - Can not get 001238 20220331 main shareholders info
# 2024-04-11 11:24:06,755 - root - WARNING - Can not get 001238 20220630 main shareholders info
# 2024-04-11 11:24:06,755 - WARNING - Can not get 001238 20220630 main shareholders info
#   9%|▊         | 459/5363 [02:59<2:35:37,  1.90s/it]2024-04-11 11:24:07,323 - root - WARNING - Can not get 001239 20210331 main shareholders info
# 2024-04-11 11:24:07,323 - WARNING - Can not get 001239 20210331 main shareholders info
# 2024-04-11 11:24:07,969 - root - WARNING - Can not get 001239 20210630 main shareholders info
# 2024-04-11 11:24:07,969 - WARNING - Can not get 001239 20210630 main shareholders info
# 2024-04-11 11:24:08,229 - root - WARNING - Can not get 001239 20210930 main shareholders info
# 2024-04-11 11:24:08,229 - WARNING - Can not get 001239 20210930 main shareholders info
# 2024-04-11 11:24:08,449 - root - WARNING - Can not get 001239 20211231 main shareholders info
# 2024-04-11 11:24:08,449 - WARNING - Can not get 001239 20211231 main shareholders info
# 2024-04-11 11:24:08,704 - root - WARNING - Can not get 001239 20220331 main shareholders info
# 2024-04-11 11:24:08,704 - WARNING - Can not get 001239 20220331 main shareholders info
# 2024-04-11 11:24:09,043 - root - WARNING - Can not get 001239 20220630 main shareholders info
# 2024-04-11 11:24:09,043 - WARNING - Can not get 001239 20220630 main shareholders info
# 2024-04-11 11:24:09,350 - root - WARNING - Can not get 001239 20220930 main shareholders info
# 2024-04-11 11:24:09,350 - WARNING - Can not get 001239 20220930 main shareholders info
# 2024-04-11 11:24:09,848 - root - WARNING - Can not get 001239 20221231 main shareholders info
# 2024-04-11 11:24:09,848 - WARNING - Can not get 001239 20221231 main shareholders info
# 2024-04-11 11:24:10,533 - root - WARNING - Can not get 001239 20230331 main shareholders info
# 2024-04-11 11:24:10,533 - WARNING - Can not get 001239 20230331 main shareholders info
# 2024-04-11 11:24:10,788 - root - WARNING - Can not get 001239 20230630 main shareholders info
# 2024-04-11 11:24:10,788 - WARNING - Can not get 001239 20230630 main shareholders info
# 2024-04-11 11:24:11,043 - root - WARNING - Can not get 001239 20230930 main shareholders info
# 2024-04-11 11:24:11,043 - WARNING - Can not get 001239 20230930 main shareholders info
# 2024-04-11 11:24:11,278 - root - WARNING - Can not get 001239 20231231 main shareholders info
# 2024-04-11 11:24:11,278 - WARNING - Can not get 001239 20231231 main shareholders info
#   9%|▊         | 460/5363 [03:03<3:32:56,  2.61s/it]2024-04-11 11:24:11,493 - root - WARNING - Can not get 001255 20210331 main shareholders info
# 2024-04-11 11:24:11,493 - WARNING - Can not get 001255 20210331 main shareholders info
# 2024-04-11 11:24:11,762 - root - WARNING - Can not get 001255 20210630 main shareholders info
# 2024-04-11 11:24:11,762 - WARNING - Can not get 001255 20210630 main shareholders info
# 2024-04-11 11:24:12,031 - root - WARNING - Can not get 001255 20210930 main shareholders info
# 2024-04-11 11:24:12,031 - WARNING - Can not get 001255 20210930 main shareholders info
# 2024-04-11 11:24:12,263 - root - WARNING - Can not get 001255 20211231 main shareholders info
# 2024-04-11 11:24:12,263 - WARNING - Can not get 001255 20211231 main shareholders info
# 2024-04-11 11:24:12,492 - root - WARNING - Can not get 001255 20220331 main shareholders info
# 2024-04-11 11:24:12,492 - WARNING - Can not get 001255 20220331 main shareholders info
# 2024-04-11 11:24:12,763 - root - WARNING - Can not get 001255 20220630 main shareholders info
# 2024-04-11 11:24:12,763 - WARNING - Can not get 001255 20220630 main shareholders info
#   9%|▊         | 461/5363 [03:05<3:15:01,  2.39s/it]2024-04-11 11:24:13,495 - root - WARNING - Can not get 001256 20210331 main shareholders info
# 2024-04-11 11:24:13,495 - WARNING - Can not get 001256 20210331 main shareholders info
# 2024-04-11 11:24:13,879 - root - WARNING - Can not get 001256 20210630 main shareholders info
# 2024-04-11 11:24:13,879 - WARNING - Can not get 001256 20210630 main shareholders info
# 2024-04-11 11:24:14,173 - root - WARNING - Can not get 001256 20210930 main shareholders info
# 2024-04-11 11:24:14,173 - WARNING - Can not get 001256 20210930 main shareholders info
# 2024-04-11 11:24:14,434 - root - WARNING - Can not get 001256 20211231 main shareholders info
# 2024-04-11 11:24:14,434 - WARNING - Can not get 001256 20211231 main shareholders info
# 2024-04-11 11:24:14,680 - root - WARNING - Can not get 001256 20220331 main shareholders info
# 2024-04-11 11:24:14,680 - WARNING - Can not get 001256 20220331 main shareholders info
# 2024-04-11 11:24:15,223 - root - WARNING - Can not get 001256 20220630 main shareholders info
# 2024-04-11 11:24:15,223 - WARNING - Can not get 001256 20220630 main shareholders info
# 2024-04-11 11:24:15,524 - root - WARNING - Can not get 001256 20220930 main shareholders info
# 2024-04-11 11:24:15,524 - WARNING - Can not get 001256 20220930 main shareholders info
#   9%|▊         | 462/5363 [03:08<3:21:51,  2.47s/it]2024-04-11 11:24:16,054 - root - WARNING - Can not get 001258 20210331 main shareholders info
# 2024-04-11 11:24:16,054 - WARNING - Can not get 001258 20210331 main shareholders info
# 2024-04-11 11:24:16,335 - root - WARNING - Can not get 001258 20210630 main shareholders info
# 2024-04-11 11:24:16,335 - WARNING - Can not get 001258 20210630 main shareholders info
# 2024-04-11 11:24:16,635 - root - WARNING - Can not get 001258 20210930 main shareholders info
# 2024-04-11 11:24:16,635 - WARNING - Can not get 001258 20210930 main shareholders info
# 2024-04-11 11:24:16,962 - root - WARNING - Can not get 001258 20211231 main shareholders info
# 2024-04-11 11:24:16,962 - WARNING - Can not get 001258 20211231 main shareholders info
# 2024-04-11 11:24:17,289 - root - WARNING - Can not get 001258 20220331 main shareholders info
# 2024-04-11 11:24:17,289 - WARNING - Can not get 001258 20220331 main shareholders info
#   9%|▊         | 463/5363 [03:09<3:04:20,  2.26s/it]2024-04-11 11:24:17,831 - root - WARNING - Can not get 001259 20210331 main shareholders info
# 2024-04-11 11:24:17,831 - WARNING - Can not get 001259 20210331 main shareholders info
# 2024-04-11 11:24:18,099 - root - WARNING - Can not get 001259 20210630 main shareholders info
# 2024-04-11 11:24:18,099 - WARNING - Can not get 001259 20210630 main shareholders info
# 2024-04-11 11:24:18,394 - root - WARNING - Can not get 001259 20210930 main shareholders info
# 2024-04-11 11:24:18,394 - WARNING - Can not get 001259 20210930 main shareholders info
# 2024-04-11 11:24:18,700 - root - WARNING - Can not get 001259 20211231 main shareholders info
# 2024-04-11 11:24:18,700 - WARNING - Can not get 001259 20211231 main shareholders info
# 2024-04-11 11:24:19,024 - root - WARNING - Can not get 001259 20220331 main shareholders info
# 2024-04-11 11:24:19,024 - WARNING - Can not get 001259 20220331 main shareholders info
# 2024-04-11 11:24:19,323 - root - WARNING - Can not get 001259 20220630 main shareholders info
# 2024-04-11 11:24:19,323 - WARNING - Can not get 001259 20220630 main shareholders info
#   9%|▊         | 464/5363 [03:11<3:00:02,  2.21s/it]2024-04-11 11:24:19,995 - root - WARNING - Can not get 001260 20210331 main shareholders info
# 2024-04-11 11:24:19,995 - WARNING - Can not get 001260 20210331 main shareholders info
# 2024-04-11 11:24:20,341 - root - WARNING - Can not get 001260 20210630 main shareholders info
# 2024-04-11 11:24:20,341 - WARNING - Can not get 001260 20210630 main shareholders info
# 2024-04-11 11:24:20,597 - root - WARNING - Can not get 001260 20210930 main shareholders info
# 2024-04-11 11:24:20,597 - WARNING - Can not get 001260 20210930 main shareholders info
# 2024-04-11 11:24:20,865 - root - WARNING - Can not get 001260 20211231 main shareholders info
# 2024-04-11 11:24:20,865 - WARNING - Can not get 001260 20211231 main shareholders info
# 2024-04-11 11:24:21,136 - root - WARNING - Can not get 001260 20220331 main shareholders info
# 2024-04-11 11:24:21,136 - WARNING - Can not get 001260 20220331 main shareholders info
# 2024-04-11 11:24:21,445 - root - WARNING - Can not get 001260 20220630 main shareholders info
# 2024-04-11 11:24:21,445 - WARNING - Can not get 001260 20220630 main shareholders info
# 2024-04-11 11:24:21,903 - root - WARNING - Can not get 001260 20220930 main shareholders info
# 2024-04-11 11:24:21,903 - WARNING - Can not get 001260 20220930 main shareholders info
#   9%|▊         | 465/5363 [03:14<3:09:14,  2.32s/it]2024-04-11 11:24:22,554 - root - WARNING - Can not get 001266 20210331 main shareholders info
# 2024-04-11 11:24:22,554 - WARNING - Can not get 001266 20210331 main shareholders info
# 2024-04-11 11:24:22,879 - root - WARNING - Can not get 001266 20210630 main shareholders info
# 2024-04-11 11:24:22,879 - WARNING - Can not get 001266 20210630 main shareholders info
# 2024-04-11 11:24:23,312 - root - WARNING - Can not get 001266 20210930 main shareholders info
# 2024-04-11 11:24:23,312 - WARNING - Can not get 001266 20210930 main shareholders info
# 2024-04-11 11:24:23,619 - root - WARNING - Can not get 001266 20211231 main shareholders info
# 2024-04-11 11:24:23,619 - WARNING - Can not get 001266 20211231 main shareholders info
#   9%|▊         | 467/5363 [03:16<2:11:54,  1.62s/it]2024-04-11 11:24:24,696 - root - WARNING - Can not get 001268 20210331 main shareholders info
# 2024-04-11 11:24:24,696 - WARNING - Can not get 001268 20210331 main shareholders info
# 2024-04-11 11:24:24,989 - root - WARNING - Can not get 001268 20210630 main shareholders info
# 2024-04-11 11:24:24,989 - WARNING - Can not get 001268 20210630 main shareholders info
# 2024-04-11 11:24:25,249 - root - WARNING - Can not get 001268 20210930 main shareholders info
# 2024-04-11 11:24:25,249 - WARNING - Can not get 001268 20210930 main shareholders info
# 2024-04-11 11:24:25,535 - root - WARNING - Can not get 001268 20211231 main shareholders info
# 2024-04-11 11:24:25,535 - WARNING - Can not get 001268 20211231 main shareholders info
# 2024-04-11 11:24:25,818 - root - WARNING - Can not get 001268 20220331 main shareholders info
# 2024-04-11 11:24:25,818 - WARNING - Can not get 001268 20220331 main shareholders info
#   9%|▊         | 468/5363 [03:18<2:13:25,  1.64s/it]2024-04-11 11:24:26,360 - root - WARNING - Can not get 001269 20210331 main shareholders info
# 2024-04-11 11:24:26,360 - WARNING - Can not get 001269 20210331 main shareholders info
# 2024-04-11 11:24:26,687 - root - WARNING - Can not get 001269 20210630 main shareholders info
# 2024-04-11 11:24:26,687 - WARNING - Can not get 001269 20210630 main shareholders info
# 2024-04-11 11:24:26,953 - root - WARNING - Can not get 001269 20210930 main shareholders info
# 2024-04-11 11:24:26,953 - WARNING - Can not get 001269 20210930 main shareholders info
# 2024-04-11 11:24:27,205 - root - WARNING - Can not get 001269 20211231 main shareholders info
# 2024-04-11 11:24:27,205 - WARNING - Can not get 001269 20211231 main shareholders info
# 2024-04-11 11:24:28,037 - root - WARNING - Can not get 001269 20220331 main shareholders info
# 2024-04-11 11:24:28,037 - WARNING - Can not get 001269 20220331 main shareholders info
# 2024-04-11 11:24:28,330 - root - WARNING - Can not get 001269 20220630 main shareholders info
# 2024-04-11 11:24:28,330 - WARNING - Can not get 001269 20220630 main shareholders info
#   9%|▊         | 469/5363 [03:21<2:39:49,  1.96s/it]2024-04-11 11:24:29,075 - root - WARNING - Can not get 001270 20210331 main shareholders info
# 2024-04-11 11:24:29,075 - WARNING - Can not get 001270 20210331 main shareholders info
# 2024-04-11 11:24:29,290 - root - WARNING - Can not get 001270 20210630 main shareholders info
# 2024-04-11 11:24:29,290 - WARNING - Can not get 001270 20210630 main shareholders info
# 2024-04-11 11:24:29,575 - root - WARNING - Can not get 001270 20210930 main shareholders info
# 2024-04-11 11:24:29,575 - WARNING - Can not get 001270 20210930 main shareholders info
# 2024-04-11 11:24:29,826 - root - WARNING - Can not get 001270 20211231 main shareholders info
# 2024-04-11 11:24:29,826 - WARNING - Can not get 001270 20211231 main shareholders info
# 2024-04-11 11:24:30,085 - root - WARNING - Can not get 001270 20220331 main shareholders info
# 2024-04-11 11:24:30,085 - WARNING - Can not get 001270 20220331 main shareholders info
#   9%|▉         | 470/5363 [03:22<2:30:19,  1.84s/it]2024-04-11 11:24:30,600 - root - WARNING - Can not get 001278 20210331 main shareholders info
# 2024-04-11 11:24:30,600 - WARNING - Can not get 001278 20210331 main shareholders info
# 2024-04-11 11:24:30,919 - root - WARNING - Can not get 001278 20210630 main shareholders info
# 2024-04-11 11:24:30,919 - WARNING - Can not get 001278 20210630 main shareholders info
# 2024-04-11 11:24:31,331 - root - WARNING - Can not get 001278 20210930 main shareholders info
# 2024-04-11 11:24:31,331 - WARNING - Can not get 001278 20210930 main shareholders info
# 2024-04-11 11:24:31,657 - root - WARNING - Can not get 001278 20211231 main shareholders info
# 2024-04-11 11:24:31,657 - WARNING - Can not get 001278 20211231 main shareholders info
# 2024-04-11 11:24:31,946 - root - WARNING - Can not get 001278 20220331 main shareholders info
# 2024-04-11 11:24:31,946 - WARNING - Can not get 001278 20220331 main shareholders info
# 2024-04-11 11:24:32,202 - root - WARNING - Can not get 001278 20220630 main shareholders info
# 2024-04-11 11:24:32,202 - WARNING - Can not get 001278 20220630 main shareholders info
# 2024-04-11 11:24:32,442 - root - WARNING - Can not get 001278 20220930 main shareholders info
# 2024-04-11 11:24:32,442 - WARNING - Can not get 001278 20220930 main shareholders info
#   9%|▉         | 471/5363 [03:25<2:44:05,  2.01s/it]2024-04-11 11:24:33,416 - root - WARNING - Can not get 001282 20210331 main shareholders info
# 2024-04-11 11:24:33,416 - WARNING - Can not get 001282 20210331 main shareholders info
# 2024-04-11 11:24:33,750 - root - WARNING - Can not get 001282 20210630 main shareholders info
# 2024-04-11 11:24:33,750 - WARNING - Can not get 001282 20210630 main shareholders info
# 2024-04-11 11:24:34,069 - root - WARNING - Can not get 001282 20210930 main shareholders info
# 2024-04-11 11:24:34,069 - WARNING - Can not get 001282 20210930 main shareholders info
# 2024-04-11 11:24:34,308 - root - WARNING - Can not get 001282 20211231 main shareholders info
# 2024-04-11 11:24:34,308 - WARNING - Can not get 001282 20211231 main shareholders info
# 2024-04-11 11:24:34,587 - root - WARNING - Can not get 001282 20220331 main shareholders info
# 2024-04-11 11:24:34,587 - WARNING - Can not get 001282 20220331 main shareholders info
# 2024-04-11 11:24:34,848 - root - WARNING - Can not get 001282 20220630 main shareholders info
# 2024-04-11 11:24:34,848 - WARNING - Can not get 001282 20220630 main shareholders info
# 2024-04-11 11:24:35,161 - root - WARNING - Can not get 001282 20220930 main shareholders info
# 2024-04-11 11:24:35,161 - WARNING - Can not get 001282 20220930 main shareholders info
# 2024-04-11 11:24:35,396 - root - WARNING - Can not get 001282 20221231 main shareholders info
# 2024-04-11 11:24:35,396 - WARNING - Can not get 001282 20221231 main shareholders info
# 2024-04-11 11:24:35,691 - root - WARNING - Can not get 001282 20230331 main shareholders info
# 2024-04-11 11:24:35,691 - WARNING - Can not get 001282 20230331 main shareholders info
#   9%|▉         | 472/5363 [03:28<3:13:36,  2.38s/it]2024-04-11 11:24:36,252 - root - WARNING - Can not get 001283 20210331 main shareholders info
# 2024-04-11 11:24:36,252 - WARNING - Can not get 001283 20210331 main shareholders info
# 2024-04-11 11:24:36,541 - root - WARNING - Can not get 001283 20210630 main shareholders info
# 2024-04-11 11:24:36,541 - WARNING - Can not get 001283 20210630 main shareholders info
# 2024-04-11 11:24:36,913 - root - WARNING - Can not get 001283 20210930 main shareholders info
# 2024-04-11 11:24:36,913 - WARNING - Can not get 001283 20210930 main shareholders info
# 2024-04-11 11:24:37,211 - root - WARNING - Can not get 001283 20211231 main shareholders info
# 2024-04-11 11:24:37,211 - WARNING - Can not get 001283 20211231 main shareholders info
# 2024-04-11 11:24:37,504 - root - WARNING - Can not get 001283 20220331 main shareholders info
# 2024-04-11 11:24:37,504 - WARNING - Can not get 001283 20220331 main shareholders info
# 2024-04-11 11:24:37,800 - root - WARNING - Can not get 001283 20220630 main shareholders info
# 2024-04-11 11:24:37,800 - WARNING - Can not get 001283 20220630 main shareholders info
#   9%|▉         | 473/5363 [03:30<3:06:41,  2.29s/it]2024-04-11 11:24:38,362 - root - WARNING - Can not get 001286 20210331 main shareholders info
# 2024-04-11 11:24:38,362 - WARNING - Can not get 001286 20210331 main shareholders info
# 2024-04-11 11:24:38,588 - root - WARNING - Can not get 001286 20210630 main shareholders info
# 2024-04-11 11:24:38,588 - WARNING - Can not get 001286 20210630 main shareholders info
# 2024-04-11 11:24:38,838 - root - WARNING - Can not get 001286 20210930 main shareholders info
# 2024-04-11 11:24:38,838 - WARNING - Can not get 001286 20210930 main shareholders info
# 2024-04-11 11:24:39,088 - root - WARNING - Can not get 001286 20211231 main shareholders info
# 2024-04-11 11:24:39,088 - WARNING - Can not get 001286 20211231 main shareholders info
# 2024-04-11 11:24:39,368 - root - WARNING - Can not get 001286 20220331 main shareholders info
# 2024-04-11 11:24:39,368 - WARNING - Can not get 001286 20220331 main shareholders info
# 2024-04-11 11:24:39,766 - root - WARNING - Can not get 001286 20220630 main shareholders info
# 2024-04-11 11:24:39,766 - WARNING - Can not get 001286 20220630 main shareholders info
# 2024-04-11 11:24:40,171 - root - WARNING - Can not get 001286 20220930 main shareholders info
# 2024-04-11 11:24:40,171 - WARNING - Can not get 001286 20220930 main shareholders info
# 2024-04-11 11:24:40,462 - root - WARNING - Can not get 001286 20221231 main shareholders info
# 2024-04-11 11:24:40,462 - WARNING - Can not get 001286 20221231 main shareholders info
#   9%|▉         | 474/5363 [03:32<3:15:44,  2.40s/it]2024-04-11 11:24:40,998 - root - WARNING - Can not get 001287 20210331 main shareholders info
# 2024-04-11 11:24:40,998 - WARNING - Can not get 001287 20210331 main shareholders info
# 2024-04-11 11:24:41,241 - root - WARNING - Can not get 001287 20210630 main shareholders info
# 2024-04-11 11:24:41,241 - WARNING - Can not get 001287 20210630 main shareholders info
# 2024-04-11 11:24:41,493 - root - WARNING - Can not get 001287 20210930 main shareholders info
# 2024-04-11 11:24:41,493 - WARNING - Can not get 001287 20210930 main shareholders info
# 2024-04-11 11:24:41,741 - root - WARNING - Can not get 001287 20211231 main shareholders info
# 2024-04-11 11:24:41,741 - WARNING - Can not get 001287 20211231 main shareholders info
# 2024-04-11 11:24:42,024 - root - WARNING - Can not get 001287 20220331 main shareholders info
# 2024-04-11 11:24:42,024 - WARNING - Can not get 001287 20220331 main shareholders info
# 2024-04-11 11:24:42,242 - root - WARNING - Can not get 001287 20220630 main shareholders info
# 2024-04-11 11:24:42,242 - WARNING - Can not get 001287 20220630 main shareholders info
# 2024-04-11 11:24:42,497 - root - WARNING - Can not get 001287 20220930 main shareholders info
# 2024-04-11 11:24:42,497 - WARNING - Can not get 001287 20220930 main shareholders info
#   9%|▉         | 475/5363 [03:35<3:07:15,  2.30s/it]2024-04-11 11:24:43,097 - root - WARNING - Can not get 001288 20210331 main shareholders info
# 2024-04-11 11:24:43,097 - WARNING - Can not get 001288 20210331 main shareholders info
# 2024-04-11 11:24:43,352 - root - WARNING - Can not get 001288 20210630 main shareholders info
# 2024-04-11 11:24:43,352 - WARNING - Can not get 001288 20210630 main shareholders info
# 2024-04-11 11:24:43,584 - root - WARNING - Can not get 001288 20210930 main shareholders info
# 2024-04-11 11:24:43,584 - WARNING - Can not get 001288 20210930 main shareholders info
#   9%|▉         | 476/5363 [03:36<2:40:11,  1.97s/it]2024-04-11 11:24:44,303 - root - WARNING - Can not get 001289 20210331 main shareholders info
# 2024-04-11 11:24:44,303 - WARNING - Can not get 001289 20210331 main shareholders info
# 2024-04-11 11:24:44,598 - root - WARNING - Can not get 001289 20210630 main shareholders info
# 2024-04-11 11:24:44,598 - WARNING - Can not get 001289 20210630 main shareholders info
# 2024-04-11 11:24:44,850 - root - WARNING - Can not get 001289 20210930 main shareholders info
# 2024-04-11 11:24:44,850 - WARNING - Can not get 001289 20210930 main shareholders info
#   9%|▉         | 477/5363 [03:37<2:18:34,  1.70s/it]2024-04-11 11:24:45,335 - root - WARNING - Can not get 001296 20210331 main shareholders info
# 2024-04-11 11:24:45,335 - WARNING - Can not get 001296 20210331 main shareholders info
# 2024-04-11 11:24:45,603 - root - WARNING - Can not get 001296 20210630 main shareholders info
# 2024-04-11 11:24:45,603 - WARNING - Can not get 001296 20210630 main shareholders info
# 2024-04-11 11:24:45,846 - root - WARNING - Can not get 001296 20210930 main shareholders info
# 2024-04-11 11:24:45,846 - WARNING - Can not get 001296 20210930 main shareholders info
#   9%|▉         | 478/5363 [03:38<2:03:46,  1.52s/it]2024-04-11 11:24:46,480 - root - WARNING - Can not get 001298 20210331 main shareholders info
# 2024-04-11 11:24:46,480 - WARNING - Can not get 001298 20210331 main shareholders info
# 2024-04-11 11:24:46,695 - root - WARNING - Can not get 001298 20210630 main shareholders info
# 2024-04-11 11:24:46,695 - WARNING - Can not get 001298 20210630 main shareholders info
# 2024-04-11 11:24:46,967 - root - WARNING - Can not get 001298 20210930 main shareholders info
# 2024-04-11 11:24:46,967 - WARNING - Can not get 001298 20210930 main shareholders info
# 2024-04-11 11:24:47,259 - root - WARNING - Can not get 001298 20211231 main shareholders info
# 2024-04-11 11:24:47,259 - WARNING - Can not get 001298 20211231 main shareholders info
# 2024-04-11 11:24:47,537 - root - WARNING - Can not get 001298 20220331 main shareholders info
# 2024-04-11 11:24:47,537 - WARNING - Can not get 001298 20220331 main shareholders info
# 2024-04-11 11:24:47,827 - root - WARNING - Can not get 001298 20220630 main shareholders info
# 2024-04-11 11:24:47,827 - WARNING - Can not get 001298 20220630 main shareholders info
# 2024-04-11 11:24:48,072 - root - WARNING - Can not get 001298 20220930 main shareholders info
# 2024-04-11 11:24:48,072 - WARNING - Can not get 001298 20220930 main shareholders info
#   9%|▉         | 479/5363 [03:40<2:19:31,  1.71s/it]2024-04-11 11:24:48,610 - root - WARNING - Can not get 001299 20210331 main shareholders info
# 2024-04-11 11:24:48,610 - WARNING - Can not get 001299 20210331 main shareholders info
# 2024-04-11 11:24:49,028 - root - WARNING - Can not get 001299 20210630 main shareholders info
# 2024-04-11 11:24:49,028 - WARNING - Can not get 001299 20210630 main shareholders info
# 2024-04-11 11:24:49,463 - root - WARNING - Can not get 001299 20210930 main shareholders info
# 2024-04-11 11:24:49,463 - WARNING - Can not get 001299 20210930 main shareholders info
# 2024-04-11 11:24:49,749 - root - WARNING - Can not get 001299 20211231 main shareholders info
# 2024-04-11 11:24:49,749 - WARNING - Can not get 001299 20211231 main shareholders info
# 2024-04-11 11:24:49,975 - root - WARNING - Can not get 001299 20220331 main shareholders info
# 2024-04-11 11:24:49,975 - WARNING - Can not get 001299 20220331 main shareholders info
# 2024-04-11 11:24:50,254 - root - WARNING - Can not get 001299 20220630 main shareholders info
# 2024-04-11 11:24:50,254 - WARNING - Can not get 001299 20220630 main shareholders info
# 2024-04-11 11:24:50,521 - root - WARNING - Can not get 001299 20220930 main shareholders info
# 2024-04-11 11:24:50,521 - WARNING - Can not get 001299 20220930 main shareholders info
#   9%|▉         | 480/5363 [03:43<2:41:11,  1.98s/it]2024-04-11 11:24:51,195 - root - WARNING - Can not get 001300 20210331 main shareholders info
# 2024-04-11 11:24:51,195 - WARNING - Can not get 001300 20210331 main shareholders info
# 2024-04-11 11:24:51,496 - root - WARNING - Can not get 001300 20210630 main shareholders info
# 2024-04-11 11:24:51,496 - WARNING - Can not get 001300 20210630 main shareholders info
# 2024-04-11 11:24:51,814 - root - WARNING - Can not get 001300 20210930 main shareholders info
# 2024-04-11 11:24:51,814 - WARNING - Can not get 001300 20210930 main shareholders info
# 2024-04-11 11:24:52,051 - root - WARNING - Can not get 001300 20211231 main shareholders info
# 2024-04-11 11:24:52,051 - WARNING - Can not get 001300 20211231 main shareholders info
# 2024-04-11 11:24:52,326 - root - WARNING - Can not get 001300 20220331 main shareholders info
# 2024-04-11 11:24:52,326 - WARNING - Can not get 001300 20220331 main shareholders info
# 2024-04-11 11:24:52,579 - root - WARNING - Can not get 001300 20220630 main shareholders info
# 2024-04-11 11:24:52,579 - WARNING - Can not get 001300 20220630 main shareholders info
#   9%|▉         | 481/5363 [03:45<2:45:01,  2.03s/it]2024-04-11 11:24:53,426 - root - WARNING - Can not get 001301 20210331 main shareholders info
# 2024-04-11 11:24:53,426 - WARNING - Can not get 001301 20210331 main shareholders info
# 2024-04-11 11:24:53,696 - root - WARNING - Can not get 001301 20210630 main shareholders info
# 2024-04-11 11:24:53,696 - WARNING - Can not get 001301 20210630 main shareholders info
# 2024-04-11 11:24:53,931 - root - WARNING - Can not get 001301 20210930 main shareholders info
# 2024-04-11 11:24:53,931 - WARNING - Can not get 001301 20210930 main shareholders info
# 2024-04-11 11:24:54,183 - root - WARNING - Can not get 001301 20211231 main shareholders info
# 2024-04-11 11:24:54,183 - WARNING - Can not get 001301 20211231 main shareholders info
# 2024-04-11 11:24:54,520 - root - WARNING - Can not get 001301 20220331 main shareholders info
# 2024-04-11 11:24:54,520 - WARNING - Can not get 001301 20220331 main shareholders info
# 2024-04-11 11:24:54,809 - root - WARNING - Can not get 001301 20220630 main shareholders info
# 2024-04-11 11:24:54,809 - WARNING - Can not get 001301 20220630 main shareholders info
# 2024-04-11 11:24:55,039 - root - WARNING - Can not get 001301 20220930 main shareholders info
# 2024-04-11 11:24:55,039 - WARNING - Can not get 001301 20220930 main shareholders info
#   9%|▉         | 482/5363 [03:47<2:50:18,  2.09s/it]2024-04-11 11:24:55,592 - root - WARNING - Can not get 001306 20210331 main shareholders info
# 2024-04-11 11:24:55,592 - WARNING - Can not get 001306 20210331 main shareholders info
# 2024-04-11 11:24:55,854 - root - WARNING - Can not get 001306 20210630 main shareholders info
# 2024-04-11 11:24:55,854 - WARNING - Can not get 001306 20210630 main shareholders info
# 2024-04-11 11:24:56,117 - root - WARNING - Can not get 001306 20210930 main shareholders info
# 2024-04-11 11:24:56,117 - WARNING - Can not get 001306 20210930 main shareholders info
# 2024-04-11 11:24:56,409 - root - WARNING - Can not get 001306 20211231 main shareholders info
# 2024-04-11 11:24:56,409 - WARNING - Can not get 001306 20211231 main shareholders info
# 2024-04-11 11:24:56,646 - root - WARNING - Can not get 001306 20220331 main shareholders info
# 2024-04-11 11:24:56,646 - WARNING - Can not get 001306 20220331 main shareholders info
# 2024-04-11 11:24:56,979 - root - WARNING - Can not get 001306 20220630 main shareholders info
# 2024-04-11 11:24:56,979 - WARNING - Can not get 001306 20220630 main shareholders info
# 2024-04-11 11:24:57,212 - root - WARNING - Can not get 001306 20220930 main shareholders info
# 2024-04-11 11:24:57,212 - WARNING - Can not get 001306 20220930 main shareholders info
# 2024-04-11 11:24:57,581 - root - WARNING - Can not get 001306 20221231 main shareholders info
# 2024-04-11 11:24:57,581 - WARNING - Can not get 001306 20221231 main shareholders info
# 2024-04-11 11:24:57,892 - root - WARNING - Can not get 001306 20230331 main shareholders info
# 2024-04-11 11:24:57,892 - WARNING - Can not get 001306 20230331 main shareholders info
# 2024-04-11 11:24:58,177 - root - WARNING - Can not get 001306 20230630 main shareholders info
# 2024-04-11 11:24:58,177 - WARNING - Can not get 001306 20230630 main shareholders info
# 2024-04-11 11:24:58,450 - root - WARNING - Can not get 001306 20230930 main shareholders info
# 2024-04-11 11:24:58,450 - WARNING - Can not get 001306 20230930 main shareholders info
# 2024-04-11 11:24:58,734 - root - WARNING - Can not get 001306 20231231 main shareholders info
# 2024-04-11 11:24:58,734 - WARNING - Can not get 001306 20231231 main shareholders info
#   9%|▉         | 483/5363 [03:50<3:22:14,  2.49s/it]2024-04-11 11:24:59,034 - root - WARNING - Can not get 001308 20210331 main shareholders info
# 2024-04-11 11:24:59,034 - WARNING - Can not get 001308 20210331 main shareholders info
# 2024-04-11 11:24:59,285 - root - WARNING - Can not get 001308 20210630 main shareholders info
# 2024-04-11 11:24:59,285 - WARNING - Can not get 001308 20210630 main shareholders info
# 2024-04-11 11:24:59,571 - root - WARNING - Can not get 001308 20210930 main shareholders info
# 2024-04-11 11:24:59,571 - WARNING - Can not get 001308 20210930 main shareholders info
# 2024-04-11 11:24:59,951 - root - WARNING - Can not get 001308 20211231 main shareholders info
# 2024-04-11 11:24:59,951 - WARNING - Can not get 001308 20211231 main shareholders info
#   9%|▉         | 484/5363 [03:52<3:00:01,  2.21s/it]2024-04-11 11:25:00,664 - root - WARNING - Can not get 001309 20210331 main shareholders info
# 2024-04-11 11:25:00,664 - WARNING - Can not get 001309 20210331 main shareholders info
# 2024-04-11 11:25:01,033 - root - WARNING - Can not get 001309 20210630 main shareholders info
# 2024-04-11 11:25:01,033 - WARNING - Can not get 001309 20210630 main shareholders info
# 2024-04-11 11:25:01,506 - root - WARNING - Can not get 001309 20210930 main shareholders info
# 2024-04-11 11:25:01,506 - WARNING - Can not get 001309 20210930 main shareholders info
# 2024-04-11 11:25:01,803 - root - WARNING - Can not get 001309 20211231 main shareholders info
# 2024-04-11 11:25:01,803 - WARNING - Can not get 001309 20211231 main shareholders info
# 2024-04-11 11:25:02,036 - root - WARNING - Can not get 001309 20220331 main shareholders info
# 2024-04-11 11:25:02,036 - WARNING - Can not get 001309 20220331 main shareholders info
#   9%|▉         | 485/5363 [03:54<2:56:23,  2.17s/it]2024-04-11 11:25:02,719 - root - WARNING - Can not get 001311 20210331 main shareholders info
# 2024-04-11 11:25:02,719 - WARNING - Can not get 001311 20210331 main shareholders info
# 2024-04-11 11:25:03,058 - root - WARNING - Can not get 001311 20210630 main shareholders info
# 2024-04-11 11:25:03,058 - WARNING - Can not get 001311 20210630 main shareholders info
# 2024-04-11 11:25:03,350 - root - WARNING - Can not get 001311 20210930 main shareholders info
# 2024-04-11 11:25:03,350 - WARNING - Can not get 001311 20210930 main shareholders info
# 2024-04-11 11:25:03,566 - root - WARNING - Can not get 001311 20211231 main shareholders info
# 2024-04-11 11:25:03,566 - WARNING - Can not get 001311 20211231 main shareholders info
# 2024-04-11 11:25:03,814 - root - WARNING - Can not get 001311 20220331 main shareholders info
# 2024-04-11 11:25:03,814 - WARNING - Can not get 001311 20220331 main shareholders info
# 2024-04-11 11:25:04,086 - root - WARNING - Can not get 001311 20220630 main shareholders info
# 2024-04-11 11:25:04,086 - WARNING - Can not get 001311 20220630 main shareholders info
# 2024-04-11 11:25:04,343 - root - WARNING - Can not get 001311 20220930 main shareholders info
# 2024-04-11 11:25:04,343 - WARNING - Can not get 001311 20220930 main shareholders info
#   9%|▉         | 486/5363 [03:56<3:00:38,  2.22s/it]2024-04-11 11:25:05,071 - root - WARNING - Can not get 001313 20210331 main shareholders info
# 2024-04-11 11:25:05,071 - WARNING - Can not get 001313 20210331 main shareholders info
# 2024-04-11 11:25:05,290 - root - WARNING - Can not get 001313 20210630 main shareholders info
# 2024-04-11 11:25:05,290 - WARNING - Can not get 001313 20210630 main shareholders info
# 2024-04-11 11:25:05,545 - root - WARNING - Can not get 001313 20210930 main shareholders info
# 2024-04-11 11:25:05,545 - WARNING - Can not get 001313 20210930 main shareholders info
# ...
# 2024-04-11 14:46:09,701 - root - WARNING - Can not get 873679 20230930 main shareholders info
# 2024-04-11 14:46:09,701 - WARNING - Can not get 873679 20230930 main shareholders info
# 2024-04-11 14:46:10,024 - root - WARNING - Can not get 873679 20231231 main shareholders info
# 2024-04-11 14:46:10,024 - WARNING - Can not get 873679 20231231 main shareholders info
# 100%|█████████▉| 5356/5363 [3:25:02<00:26,  3.84s/it]2024-04-11 14:46:10,361 - root - WARNING - Can not get 873690 20210331 main shareholders info
# 2024-04-11 14:46:10,361 - WARNING - Can not get 873690 20210331 main shareholders info
# 2024-04-11 14:46:10,659 - root - WARNING - Can not get 873690 20210630 main shareholders info
# 2024-04-11 14:46:10,659 - WARNING - Can not get 873690 20210630 main shareholders info
# 2024-04-11 14:46:10,903 - root - WARNING - Can not get 873690 20210930 main shareholders info
# 2024-04-11 14:46:10,903 - WARNING - Can not get 873690 20210930 main shareholders info
# 2024-04-11 14:46:11,269 - root - WARNING - Can not get 873690 20211231 main shareholders info
# 2024-04-11 14:46:11,269 - WARNING - Can not get 873690 20211231 main shareholders info
# 2024-04-11 14:46:11,608 - root - WARNING - Can not get 873690 20220331 main shareholders info
# 2024-04-11 14:46:11,608 - WARNING - Can not get 873690 20220331 main shareholders info
# 2024-04-11 14:46:11,927 - root - WARNING - Can not get 873690 20220630 main shareholders info
# 2024-04-11 14:46:11,927 - WARNING - Can not get 873690 20220630 main shareholders info
# 2024-04-11 14:46:12,267 - root - WARNING - Can not get 873690 20220930 main shareholders info
# 2024-04-11 14:46:12,267 - WARNING - Can not get 873690 20220930 main shareholders info
# 2024-04-11 14:46:12,580 - root - WARNING - Can not get 873690 20221231 main shareholders info
# 2024-04-11 14:46:12,580 - WARNING - Can not get 873690 20221231 main shareholders info
# 2024-04-11 14:46:12,877 - root - WARNING - Can not get 873690 20230331 main shareholders info
# 2024-04-11 14:46:12,877 - WARNING - Can not get 873690 20230331 main shareholders info
# 2024-04-11 14:46:13,193 - root - WARNING - Can not get 873690 20230630 main shareholders info
# 2024-04-11 14:46:13,193 - WARNING - Can not get 873690 20230630 main shareholders info
# 2024-04-11 14:46:13,527 - root - WARNING - Can not get 873690 20230930 main shareholders info
# 2024-04-11 14:46:13,527 - WARNING - Can not get 873690 20230930 main shareholders info
# 2024-04-11 14:46:13,848 - root - WARNING - Can not get 873690 20231231 main shareholders info
# 2024-04-11 14:46:13,848 - WARNING - Can not get 873690 20231231 main shareholders info
# 100%|█████████▉| 5357/5363 [3:25:06<00:22,  3.83s/it]2024-04-11 14:46:14,194 - root - WARNING - Can not get 873693 20210331 main shareholders info
# 2024-04-11 14:46:14,194 - WARNING - Can not get 873693 20210331 main shareholders info
# 2024-04-11 14:46:14,538 - root - WARNING - Can not get 873693 20210630 main shareholders info
# 2024-04-11 14:46:14,538 - WARNING - Can not get 873693 20210630 main shareholders info
# 2024-04-11 14:46:14,848 - root - WARNING - Can not get 873693 20210930 main shareholders info
# 2024-04-11 14:46:14,848 - WARNING - Can not get 873693 20210930 main shareholders info
# 2024-04-11 14:46:15,225 - root - WARNING - Can not get 873693 20211231 main shareholders info
# 2024-04-11 14:46:15,225 - WARNING - Can not get 873693 20211231 main shareholders info
# 2024-04-11 14:46:15,597 - root - WARNING - Can not get 873693 20220331 main shareholders info
# 2024-04-11 14:46:15,597 - WARNING - Can not get 873693 20220331 main shareholders info
# 2024-04-11 14:46:15,930 - root - WARNING - Can not get 873693 20220630 main shareholders info
# 2024-04-11 14:46:15,930 - WARNING - Can not get 873693 20220630 main shareholders info
# 2024-04-11 14:46:16,252 - root - WARNING - Can not get 873693 20220930 main shareholders info
# 2024-04-11 14:46:16,252 - WARNING - Can not get 873693 20220930 main shareholders info
# 2024-04-11 14:46:16,562 - root - WARNING - Can not get 873693 20221231 main shareholders info
# 2024-04-11 14:46:16,562 - WARNING - Can not get 873693 20221231 main shareholders info
# 2024-04-11 14:46:16,867 - root - WARNING - Can not get 873693 20230331 main shareholders info
# 2024-04-11 14:46:16,867 - WARNING - Can not get 873693 20230331 main shareholders info
# 2024-04-11 14:46:17,212 - root - WARNING - Can not get 873693 20230630 main shareholders info
# 2024-04-11 14:46:17,212 - WARNING - Can not get 873693 20230630 main shareholders info
# 2024-04-11 14:46:17,613 - root - WARNING - Can not get 873693 20230930 main shareholders info
# 2024-04-11 14:46:17,613 - WARNING - Can not get 873693 20230930 main shareholders info
# 2024-04-11 14:46:17,947 - root - WARNING - Can not get 873693 20231231 main shareholders info
# 2024-04-11 14:46:17,947 - WARNING - Can not get 873693 20231231 main shareholders info
# 100%|█████████▉| 5358/5363 [3:25:10<00:19,  3.91s/it]2024-04-11 14:46:18,212 - root - WARNING - Can not get 873703 20210331 main shareholders info
# 2024-04-11 14:46:18,212 - WARNING - Can not get 873703 20210331 main shareholders info
# 2024-04-11 14:46:18,513 - root - WARNING - Can not get 873703 20210630 main shareholders info
# 2024-04-11 14:46:18,513 - WARNING - Can not get 873703 20210630 main shareholders info
# 2024-04-11 14:46:18,924 - root - WARNING - Can not get 873703 20210930 main shareholders info
# 2024-04-11 14:46:18,924 - WARNING - Can not get 873703 20210930 main shareholders info
# 2024-04-11 14:46:19,252 - root - WARNING - Can not get 873703 20211231 main shareholders info
# 2024-04-11 14:46:19,252 - WARNING - Can not get 873703 20211231 main shareholders info
# 2024-04-11 14:46:19,544 - root - WARNING - Can not get 873703 20220331 main shareholders info
# 2024-04-11 14:46:19,544 - WARNING - Can not get 873703 20220331 main shareholders info
# 2024-04-11 14:46:19,936 - root - WARNING - Can not get 873703 20220630 main shareholders info
# 2024-04-11 14:46:19,936 - WARNING - Can not get 873703 20220630 main shareholders info
# 2024-04-11 14:46:20,417 - root - WARNING - Can not get 873703 20220930 main shareholders info
# 2024-04-11 14:46:20,417 - WARNING - Can not get 873703 20220930 main shareholders info
# 2024-04-11 14:46:21,026 - root - WARNING - Can not get 873703 20221231 main shareholders info
# 2024-04-11 14:46:21,026 - WARNING - Can not get 873703 20221231 main shareholders info
# 2024-04-11 14:46:21,532 - root - WARNING - Can not get 873703 20230331 main shareholders info
# 2024-04-11 14:46:21,532 - WARNING - Can not get 873703 20230331 main shareholders info
# 2024-04-11 14:46:21,976 - root - WARNING - Can not get 873703 20230630 main shareholders info
# 2024-04-11 14:46:21,976 - WARNING - Can not get 873703 20230630 main shareholders info
# 2024-04-11 14:46:22,454 - root - WARNING - Can not get 873703 20230930 main shareholders info
# 2024-04-11 14:46:22,454 - WARNING - Can not get 873703 20230930 main shareholders info
# 2024-04-11 14:46:22,856 - root - WARNING - Can not get 873703 20231231 main shareholders info
# 2024-04-11 14:46:22,856 - WARNING - Can not get 873703 20231231 main shareholders info
# 100%|█████████▉| 5359/5363 [3:25:15<00:16,  4.21s/it]2024-04-11 14:46:23,472 - root - WARNING - Can not get 873706 20210331 main shareholders info
# 2024-04-11 14:46:23,472 - WARNING - Can not get 873706 20210331 main shareholders info
# 2024-04-11 14:46:23,963 - root - WARNING - Can not get 873706 20210630 main shareholders info
# 2024-04-11 14:46:23,963 - WARNING - Can not get 873706 20210630 main shareholders info
# 2024-04-11 14:46:24,403 - root - WARNING - Can not get 873706 20210930 main shareholders info
# 2024-04-11 14:46:24,403 - WARNING - Can not get 873706 20210930 main shareholders info
# 2024-04-11 14:46:24,853 - root - WARNING - Can not get 873706 20211231 main shareholders info
# 2024-04-11 14:46:24,853 - WARNING - Can not get 873706 20211231 main shareholders info
# 2024-04-11 14:46:25,173 - root - WARNING - Can not get 873706 20220331 main shareholders info
# 2024-04-11 14:46:25,173 - WARNING - Can not get 873706 20220331 main shareholders info
# 2024-04-11 14:46:25,554 - root - WARNING - Can not get 873706 20220630 main shareholders info
# 2024-04-11 14:46:25,554 - WARNING - Can not get 873706 20220630 main shareholders info
# 2024-04-11 14:46:26,036 - root - WARNING - Can not get 873706 20220930 main shareholders info
# 2024-04-11 14:46:26,036 - WARNING - Can not get 873706 20220930 main shareholders info
# 2024-04-11 14:46:26,522 - root - WARNING - Can not get 873706 20221231 main shareholders info
# 2024-04-11 14:46:26,522 - WARNING - Can not get 873706 20221231 main shareholders info
# 2024-04-11 14:46:26,946 - root - WARNING - Can not get 873706 20230331 main shareholders info
# 2024-04-11 14:46:26,946 - WARNING - Can not get 873706 20230331 main shareholders info
# 2024-04-11 14:46:27,536 - root - WARNING - Can not get 873706 20230630 main shareholders info
# 2024-04-11 14:46:27,536 - WARNING - Can not get 873706 20230630 main shareholders info
# 2024-04-11 14:46:27,902 - root - WARNING - Can not get 873706 20230930 main shareholders info
# 2024-04-11 14:46:27,902 - WARNING - Can not get 873706 20230930 main shareholders info
# 2024-04-11 14:46:28,256 - root - WARNING - Can not get 873706 20231231 main shareholders info
# 2024-04-11 14:46:28,256 - WARNING - Can not get 873706 20231231 main shareholders info
# 100%|█████████▉| 5360/5363 [3:25:20<00:13,  4.57s/it]2024-04-11 14:46:28,728 - root - WARNING - Can not get 873726 20210331 main shareholders info
# 2024-04-11 14:46:28,728 - WARNING - Can not get 873726 20210331 main shareholders info
# 2024-04-11 14:46:29,018 - root - WARNING - Can not get 873726 20210630 main shareholders info
# 2024-04-11 14:46:29,018 - WARNING - Can not get 873726 20210630 main shareholders info
# 2024-04-11 14:46:29,362 - root - WARNING - Can not get 873726 20210930 main shareholders info
# 2024-04-11 14:46:29,362 - WARNING - Can not get 873726 20210930 main shareholders info
# 2024-04-11 14:46:29,752 - root - WARNING - Can not get 873726 20211231 main shareholders info
# 2024-04-11 14:46:29,752 - WARNING - Can not get 873726 20211231 main shareholders info
# 2024-04-11 14:46:30,035 - root - WARNING - Can not get 873726 20220331 main shareholders info
# 2024-04-11 14:46:30,035 - WARNING - Can not get 873726 20220331 main shareholders info
# 2024-04-11 14:46:30,392 - root - WARNING - Can not get 873726 20220630 main shareholders info
# 2024-04-11 14:46:30,392 - WARNING - Can not get 873726 20220630 main shareholders info
# 2024-04-11 14:46:30,669 - root - WARNING - Can not get 873726 20220930 main shareholders info
# 2024-04-11 14:46:30,669 - WARNING - Can not get 873726 20220930 main shareholders info
# 2024-04-11 14:46:31,012 - root - WARNING - Can not get 873726 20221231 main shareholders info
# 2024-04-11 14:46:31,012 - WARNING - Can not get 873726 20221231 main shareholders info
# 2024-04-11 14:46:31,327 - root - WARNING - Can not get 873726 20230331 main shareholders info
# 2024-04-11 14:46:31,327 - WARNING - Can not get 873726 20230331 main shareholders info
# 2024-04-11 14:46:31,723 - root - WARNING - Can not get 873726 20230630 main shareholders info
# 2024-04-11 14:46:31,723 - WARNING - Can not get 873726 20230630 main shareholders info
# 2024-04-11 14:46:32,056 - root - WARNING - Can not get 873726 20230930 main shareholders info
# 2024-04-11 14:46:32,056 - WARNING - Can not get 873726 20230930 main shareholders info
# 2024-04-11 14:46:32,365 - root - WARNING - Can not get 873726 20231231 main shareholders info
# 2024-04-11 14:46:32,365 - WARNING - Can not get 873726 20231231 main shareholders info
# 100%|█████████▉| 5361/5363 [3:25:24<00:08,  4.43s/it]2024-04-11 14:46:32,743 - root - WARNING - Can not get 873806 20210331 main shareholders info
# 2024-04-11 14:46:32,743 - WARNING - Can not get 873806 20210331 main shareholders info
# 2024-04-11 14:46:33,067 - root - WARNING - Can not get 873806 20210630 main shareholders info
# 2024-04-11 14:46:33,067 - WARNING - Can not get 873806 20210630 main shareholders info
# 2024-04-11 14:46:33,340 - root - WARNING - Can not get 873806 20210930 main shareholders info
# 2024-04-11 14:46:33,340 - WARNING - Can not get 873806 20210930 main shareholders info
# 2024-04-11 14:46:33,678 - root - WARNING - Can not get 873806 20211231 main shareholders info
# 2024-04-11 14:46:33,678 - WARNING - Can not get 873806 20211231 main shareholders info
# 2024-04-11 14:46:33,980 - root - WARNING - Can not get 873806 20220331 main shareholders info
# 2024-04-11 14:46:33,980 - WARNING - Can not get 873806 20220331 main shareholders info
# 2024-04-11 14:46:34,296 - root - WARNING - Can not get 873806 20220630 main shareholders info
# 2024-04-11 14:46:34,296 - WARNING - Can not get 873806 20220630 main shareholders info
# 2024-04-11 14:46:34,631 - root - WARNING - Can not get 873806 20220930 main shareholders info
# 2024-04-11 14:46:34,631 - WARNING - Can not get 873806 20220930 main shareholders info
# 2024-04-11 14:46:34,926 - root - WARNING - Can not get 873806 20221231 main shareholders info
# 2024-04-11 14:46:34,926 - WARNING - Can not get 873806 20221231 main shareholders info
# 2024-04-11 14:46:35,222 - root - WARNING - Can not get 873806 20230331 main shareholders info
# 2024-04-11 14:46:35,222 - WARNING - Can not get 873806 20230331 main shareholders info
# 2024-04-11 14:46:35,522 - root - WARNING - Can not get 873806 20230630 main shareholders info
# 2024-04-11 14:46:35,522 - WARNING - Can not get 873806 20230630 main shareholders info
# 2024-04-11 14:46:35,817 - root - WARNING - Can not get 873806 20230930 main shareholders info
# 2024-04-11 14:46:35,817 - WARNING - Can not get 873806 20230930 main shareholders info
# 2024-04-11 14:46:36,118 - root - WARNING - Can not get 873806 20231231 main shareholders info
# 2024-04-11 14:46:36,118 - WARNING - Can not get 873806 20231231 main shareholders info
# 100%|█████████▉| 5362/5363 [3:25:28<00:04,  4.23s/it]2024-04-11 14:46:36,486 - root - WARNING - Can not get 873833 20210331 main shareholders info
# 2024-04-11 14:46:36,486 - WARNING - Can not get 873833 20210331 main shareholders info
# 2024-04-11 14:46:36,827 - root - WARNING - Can not get 873833 20210630 main shareholders info
# 2024-04-11 14:46:36,827 - WARNING - Can not get 873833 20210630 main shareholders info
# 2024-04-11 14:46:37,189 - root - WARNING - Can not get 873833 20210930 main shareholders info
# 2024-04-11 14:46:37,189 - WARNING - Can not get 873833 20210930 main shareholders info
# 2024-04-11 14:46:37,476 - root - WARNING - Can not get 873833 20211231 main shareholders info
# 2024-04-11 14:46:37,476 - WARNING - Can not get 873833 20211231 main shareholders info
# 2024-04-11 14:46:37,748 - root - WARNING - Can not get 873833 20220331 main shareholders info
# 2024-04-11 14:46:37,748 - WARNING - Can not get 873833 20220331 main shareholders info
# 2024-04-11 14:46:38,098 - root - WARNING - Can not get 873833 20220630 main shareholders info
# 2024-04-11 14:46:38,098 - WARNING - Can not get 873833 20220630 main shareholders info
# 2024-04-11 14:46:38,364 - root - WARNING - Can not get 873833 20220930 main shareholders info
# 2024-04-11 14:46:38,364 - WARNING - Can not get 873833 20220930 main shareholders info
# 2024-04-11 14:46:38,612 - root - WARNING - Can not get 873833 20221231 main shareholders info
# 2024-04-11 14:46:38,612 - WARNING - Can not get 873833 20221231 main shareholders info
# 2024-04-11 14:46:38,879 - root - WARNING - Can not get 873833 20230331 main shareholders info
# 2024-04-11 14:46:38,879 - WARNING - Can not get 873833 20230331 main shareholders info
# 2024-04-11 14:46:39,173 - root - WARNING - Can not get 873833 20230630 main shareholders info
# 2024-04-11 14:46:39,173 - WARNING - Can not get 873833 20230630 main shareholders info
# 2024-04-11 14:46:39,529 - root - WARNING - Can not get 873833 20230930 main shareholders info
# 2024-04-11 14:46:39,529 - WARNING - Can not get 873833 20230930 main shareholders info
# 2024-04-11 14:46:39,880 - root - WARNING - Can not get 873833 20231231 main shareholders info
# 2024-04-11 14:46:39,880 - WARNING - Can not get 873833 20231231 main shareholders info
# 100%|██████████| 5363/5363 [3:25:32<00:00,  2.30s/it]

# %% [markdown]
# ## 5.Price Indicators

# %%
import akshare as ak

stock_zh_a_hist_df = ak.stock_zh_a_hist(symbol="001359", period="daily", start_date="20230412", end_date='20240412', adjust="hfq")
stock_zh_a_hist_df['日期'].astype(str)
# Out:
# 0    2024-03-28
# 1    2024-03-29
# 2    2024-04-01
# 3    2024-04-02
# 4    2024-04-03
# 5    2024-04-08
# 6    2024-04-09
# 7    2024-04-10
# 8    2024-04-11
# 9    2024-04-12
# Name: 日期, dtype: object

# %%
def process_date_to_report_time(date: datetime):
    date = pd.to_datetime(date)
    year = date.year
    first_season_end_date = datetime(year, 3, 31)
    second_season_end_date = datetime(year, 6, 30)
    third_season_end_date = datetime(year, 9, 30)
    last_season_end_date = datetime(year, 12, 31)
    if date < first_season_end_date:
        return first_season_end_date.strftime('%Y-%m-%d')
    if date < second_season_end_date:
        return second_season_end_date.strftime('%Y-%m-%d')
    if date < third_season_end_date:
        return third_season_end_date.strftime('%Y-%m-%d')
    if date < last_season_end_date:
        return last_season_end_date.strftime('%Y-%m-%d')
    
def MA(data, n):
    MA = pd.Series(data['收盘'].rolling(n).mean().round(2), name='MA_' + str(n))
    return MA.fillna('nan')

def EMA(data, n):
    EMA = pd.Series(data['收盘'].ewm(span=n, min_periods=n).mean().round(2), name='EMA_' + str(n))
    return EMA.fillna('nan')

def RSI(data, n):
    lc = data['收盘'].shift(1)
    diff = data['收盘'] - lc
    up = diff.where(diff > 0, 0)
    down = -diff.where(diff < 0, 0)
    ema_up = up.ewm(alpha=1/n, adjust=False).mean()
    ema_down = down.ewm(alpha=1/n, adjust=False).mean()
    rs = ema_up / ema_down
    rsi = round(100 - 100 / (1 + rs), 2)
    return pd.Series(rsi, name='RSI_' + str(n)).fillna('nan')


def MACD_Level(data, n_fast, n_slow):
    EMAfast = data['收盘'].ewm(span=n_fast, min_periods=n_slow).mean().round(2)
    EMAslow = data['收盘'].ewm(span=n_slow, min_periods=n_slow).mean().round(2)
    data['MACD'] = EMAfast - EMAslow
    data['MACDsignal'] = data['MACD'].ewm(span=9, min_periods=9).mean().round(2)
    data['MACDhist'] = data['MACD'] - data['MACDsignal']
    return data[['MACD', 'MACDsignal', 'MACDhist']].fillna('nan')

# %%
# create price data type constraint
cypher = 'CREATE CONSTRAINT IF NOT EXISTS FOR (n:行情类型) REQUIRE (n.股票代码, n.行情类型) IS UNIQUE'
graph.run(cypher=cypher)

# create price data constraint
cypher = 'CREATE CONSTRAINT IF NOT EXISTS FOR (n:行情数据) REQUIRE (n.股票代码, n.行情类型, n.报告期) IS UNIQUE'
graph.run(cypher=cypher)

# create price indicators type constraint
cypher = 'CREATE CONSTRAINT IF NOT EXISTS FOR (n:技术指标类型) REQUIRE (n.股票代码, n.技术指标类型) IS UNIQUE'
graph.run(cypher=cypher)

# create price indicatorsconstraint
cypher = 'CREATE CONSTRAINT IF NOT EXISTS FOR (n:技术指标数据) REQUIRE (n.股票代码, n.技术指标类型, n.报告期) IS UNIQUE'
graph.run(cypher=cypher)


start_date = (datetime.now() - timedelta(365)).strftime('%Y%m%d')
end_date = datetime.now().strftime('%Y%m%d')

neccessry_price_data_type = ['收盘', '成交量', '涨跌幅', '换手率']

for code in tqdm(stock_code_list):
    stock = matcher.match("股票", 代码=code).first()
    if stock is None:
        continue
    # get price info
    try:
        df_price = ak.stock_zh_a_hist(symbol=code, period="daily", start_date=start_date, end_date=end_date, adjust="hfq")
        df_price = df_price[['日期'] + neccessry_price_data_type].copy()
        df_price['报告期'] = df_price['日期'].apply(process_date_to_report_time)
        df_price['日期'] = df_price['日期'].astype(str)
        df_price['股票代码'] = code
    except:
        log.warning(f'Can not get {code} price data')
        continue
    
    for price_type in neccessry_price_data_type:
        # create price data price_type node
        price_data_type_node = Node('行情类型', 股票代码=code, 行情类型=price_type, name=price_type)
        try:
            graph.create(price_data_type_node)
        except:
            continue

        # create stock - main shareholders relationship
        stock = matcher.match("股票", 代码=code).first()
        price_data_type = matcher.match("行情类型", 股票代码=code, 行情类型=price_type).first()
        realation = Relationship(stock, '行情', price_data_type)
        try:
            graph.create(realation)
        except:
            pass

    for report_time, df in df_price.groupby('报告期'):
        for price_type in neccessry_price_data_type:
            assert price_type in df.columns, f'{price_type} not in {code} {report_time} price data'
            attribute = {}
            for date, value in df[['日期', price_type]].values:
                attribute[date] = value

            price_data_node = Node('行情数据', 股票代码=code, 行情类型=price_type, 报告期=report_time, name=report_time, **attribute)
            try:
                graph.create(price_data_node)
            except:
                continue

            # create stock - main shareholders relationship
            price_data_type = matcher.match("行情类型", 股票代码=code, 行情类型=price_type).first()
            price_data = matcher.match("行情数据", 股票代码=code, 行情类型=price_type, 报告期=report_time).first()
            realation = Relationship(price_data_type, '行情具体数据', price_data)
            try:
                graph.create(realation)
            except:
                pass
    
    df_indicators = df_price[['日期', '报告期', '收盘']].copy()
    df_indicators['MA5'] = MA(data=df_indicators, n=5)
    df_indicators['MA20'] = MA(data=df_indicators, n=20)
    df_indicators['EMA5'] = EMA(data=df_indicators, n=5)
    df_indicators['EMA20'] = EMA(data=df_indicators, n=20)
    df_indicators['RSI'] = RSI(data=df_indicators, n=14)
    df_indicators[['MACD', 'MACD_hist', 'MACD_signal']] = MACD_Level(data=df_indicators, n_fast=12, n_slow=26)
    df_indicators = df_indicators.drop('收盘', axis=1)

    indicator_name_map = {
        'MA5': '五日移动均线',
        'MA20': '二十日移动均线',
        'EMA5': '五日指数移动均线',
        'EMA20': '二十日指数移动均线',
        'RSI': '相对强弱指标',
        'MACD': 'MACD线',
        'MACD_hist': 'MACD离差图',
        'MACD_signal': 'MACD信号线'
    }
    

    for idicator_type in indicator_name_map.keys():
        # create price idicator type node
        price_idicator_type_node = Node('技术指标类型', 股票代码=code, 技术指标类型=indicator_name_map[idicator_type], name=idicator_type)
        try:
            graph.create(price_idicator_type_node)
        except:
            break

        # create stock - main shareholders relationship
        stock = matcher.match("股票", 代码=code).first()
        price_data_type = matcher.match("技术指标类型", 股票代码=code, 技术指标类型=indicator_name_map[idicator_type]).first()
        realation = Relationship(stock, '行情', price_data_type)
        try:
            graph.create(realation)
        except:
            pass

    for report_time, df in df_indicators.groupby('报告期'):
        for idicator_type in indicator_name_map.keys():
            assert idicator_type in df.columns, f'{idicator_type} not in {code} {report_time} price data'
            attribute = {}
            for date, value in df[['日期', idicator_type]].values:
                attribute[date] = value

            price_indicator_node = Node('技术指标数据', 股票代码=code, 技术指标类型=indicator_name_map[idicator_type], 
                                        报告期=report_time, name=report_time, **attribute)
            try:
                graph.create(price_indicator_node)
            except:
                break

            # create stock - main shareholders relationship
            price_indicator_type = matcher.match("技术指标类型", 股票代码=code, 技术指标类型=indicator_name_map[idicator_type]).first()
            price_indicator = matcher.match("技术指标数据", 股票代码=code, 技术指标类型=indicator_name_map[idicator_type], 报告期=report_time).first()
            realation = Relationship(price_indicator_type, '技术指标具体数据', price_indicator)
            try:
                graph.create(realation)
            except:
                pass
# Out:
# 100%|██████████| 5363/5363 [2:09:08<00:00,  1.44s/it]
